# %%
def weiter():                                                             
    weitermachen = input("Willst du weitermachen? (['y'/'n']Ja/Nein) ")
    if weitermachen == "y":
        taschenrechner()
        
def begrüßen():
    print("Hallo!\nIch bin ein Taschenrechner!\nIch kann +, -, *, /, // und % berechnen!")   

def add(zahl01, zahl02):
    print("Das Ergebnis der Addition von ",zahl01," + ",zahl02," lautet: ",zahl01 + zahl02)
    return zahl01 + zahl02

def sub(zahl01, zahl02):
    print("Das Ergebnis der Subtraktion von ",zahl01," - ",zahl02," lautet: ",zahl01 - zahl02)
    return zahl01 - zahl02

def mul(zahl01, zahl02):
    print("Das Ergebnis der Multiplikation von ",zahl01," * ",zahl02," lautet: ",zahl01 * zahl02)
    return zahl01 * zahl02

def div(zahl01, zahl02):
    print("Das Ergebnis der Division von ",zahl01," / ",zahl02," lautet: ",zahl01 / zahl02)
    return zahl01 / zahl02

def ganzdiv(zahl01, zahl02):
    print("Das Ergebnis der Ganzdivision von ",zahl01," // ",zahl02," lautet: ",zahl01 // zahl02)
    return zahl01 // zahl02

def mod(zahl01, zahl02):
    print("Das Ergebnis von Modulo von ",zahl01," % ",zahl02," lautet: ",zahl01 % zahl02)
    return zahl01 % zahl02

begrüßen()                                                       # bei def's Ergebnis zurückgeben mit return
                                                                 # nur so weiteres Verschachteln von def's möglich
def taschenrechner():

    zahl01 = int(input("Tippe eine Zahl ein: "))                 # input gleich casten mit int
    operation = input("Was willst du mit dieser Zahl tun? ")
    zahl02 = int(input("Tippe eine zweite Zahl ein: "))
    
    if operation == "+":
        add(zahl01, zahl02)
        weiter()
        
    elif operation == "-":
        sub(zahl01, zahl02)
        weiter()
        
    elif operation == "*":
        mul(zahl01, zahl02)
        weiter()
        
    elif operation == "/":
        div(zahl01, zahl02)
        weiter()
        
    elif operation == "//":
        ganzdiv(zahl01, zahl02)
        weiter()
        
    elif operation == "%":
        mod(zahl01, zahl02)
        weiter()
        
taschenrechner()
# Out:
# Hallo!
# Ich bin ein Taschenrechner!
# Ich kann +, -, *, /, // und % berechnen!
# Tippe eine Zahl ein: 5
# Was willst du mit dieser Zahl tun? +
# Tippe eine zweite Zahl ein: 3
# Das Ergebnis der Addition von  5  +  3  lautet:  8
# Willst du weitermachen? (['y'/'n']Ja/Nein) y
# Tippe eine Zahl ein: 7
# Was willst du mit dieser Zahl tun? -
# Tippe eine zweite Zahl ein: 2
# Das Ergebnis der Subtraktion von  7  -  2  lautet:  5
# Willst du weitermachen? (['y'/'n']Ja/Nein) y
# Tippe eine Zahl ein: 5
# Was willst du mit dieser Zahl tun? *
# Tippe eine zweite Zahl ein: 3
# Das Ergebnis der Multiplikation von  5  *  3  lautet:  15
# Willst du weitermachen? (['y'/'n']Ja/Nein) y
# Tippe eine Zahl ein: 10
# Was willst du mit dieser Zahl tun? /
# Tippe eine zweite Zahl ein: 2
# Das Ergebnis der Division von  10  /  2  lautet:  5.0
# Willst du weitermachen? (['y'/'n']Ja/Nein) y
# Tippe eine Zahl ein: 15
# Was willst du mit dieser Zahl tun? //
# Tippe eine zweite Zahl ein: 2
# Das Ergebnis der Ganzdivision von  15  //  2  lautet:  7
# Willst du weitermachen? (['y'/'n']Ja/Nein) y
# Tippe eine Zahl ein: 52
# Was willst du mit dieser Zahl tun? %
# Tippe eine zweite Zahl ein: 4
# Das Ergebnis von Modulo von  52  %  4  lautet:  0
# Willst du weitermachen? (['y'/'n']Ja/Nein) n
