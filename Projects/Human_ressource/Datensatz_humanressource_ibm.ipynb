# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
mitarbeiter01 = pd.read_csv("Final dataset Attrition.csv")
mitarbeiter02 = pd.read_csv("Final dataset Attrition.csv")

# %%
# Dataframe exportieren
#mitarbeiter02.to_csv("Final dataset Attrition_01.csv",index=False)

# %%
mitarbeiter01.shape
# Out:
# (1470, 33)

# %%
mitarbeiter01.head(2)
# Out:
#    Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0   37       Yes  Travel_Rarely  Research & Development                 2
# 1   21        No  Travel_Rarely  Research & Development                15
#
#   Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0   Male               2         1  Laboratory Technician                3
# 1   Male               3         1     Research Scientist                4
#
#    ... Date_of_Hire  Date_of_termination  Status_of_leaving Mode_of_work  \
# 0  ...   21-01-2021                  NaN             Salary       OFFICE
# 1  ...   13-03-2021                  NaN      Work Accident          WFH
#
#    Leaves  Absenteeism  Work_accident  Source_of_Hire   Job_mode  Unnamed: 32
# 0       4            2             No       Job Event   Contract          NaN
# 1       5            2             No       Recruiter  Part Time          NaN
#
# [2 rows x 33 columns]

# %%
mitarbeiter02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   Gender                   1470 non-null   object
#  6   JobInvolvement           1470 non-null   int64
#  7   JobLevel                 1470 non-null   int64
#  8   JobRole                  1470 non-null   object
#  9   JobSatisfaction          1470 non-null   int64
#  10  MaritalStatus            1470 non-null   object
#  11  MonthlyIncome            1470 non-null   int64
#  12  NumCompaniesWorked       1470 non-null   int64
#  13  OverTime                 1470 non-null   object
# ...

# %%
mitarbeiter02.isnull().sum()
# Out:
# Age                           0
# Attrition                     0
# BusinessTravel                0
# Department                    0
# DistanceFromHome              0
# Gender                        0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# NumCompaniesWorked            0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# YearsAtCompany                0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# Higher_Education              0
# Date_of_Hire                  0
# Date_of_termination        1470
# Status_of_leaving             0
# Mode_of_work                  0
# Leaves                        0
# Absenteeism                   0
# ...

# %%
mitarbeiter02.nunique()
# Out:
# Age                          43
# Attrition                     2
# BusinessTravel                3
# Department                    3
# DistanceFromHome             29
# Gender                        2
# JobInvolvement                4
# JobLevel                      5
# JobRole                       9
# JobSatisfaction               4
# MaritalStatus                 3
# MonthlyIncome              1349
# NumCompaniesWorked           10
# OverTime                      2
# PercentSalaryHike            15
# PerformanceRating             2
# StockOptionLevel              4
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# YearsAtCompany               37
# YearsSinceLastPromotion      16
# YearsWithCurrManager         18
# Higher_Education              4
# Date_of_Hire               1112
# Date_of_termination           0
# Status_of_leaving             5
# Mode_of_work                  2
# Leaves                        6
# Absenteeism                   4
# ...

# %% [markdown]
# # DATEN BEREINIGEN

# %%
# COLUMNS DROPEN

# %%
mitarbeiter02.drop(mitarbeiter02[["Date_of_termination", "Unnamed: 32"]], axis = 1, inplace=True)

# %%
mitarbeiter02.drop(mitarbeiter02[["Date_of_Hire", "StockOptionLevel"]], axis = 1, inplace=True)

# %%
mitarbeiter02.shape
# Out:
# (1470, 29)

# %%
# UMWANDELN KATEGORISCHE WERTE IN NUMERISCHE

# %%
# Gender
mitarbeiter02.Gender.replace({"Female" : 0, "Male" : 1}, inplace = True)

# %%
# Kündigung
mitarbeiter02.Attrition.replace({"No" : 0, "Yes" : 1}, inplace = True)

# %%
# Geschäftsreisen
mitarbeiter02.BusinessTravel.replace({"Non-Travel" : 0, "Travel_Rarely" : 1, "Travel_Frequently" : 2}, inplace = True)

# %%
# Department
mitarbeiter02.Department.replace({"Human Resources" : 0, "Sales" : 1, "Research & Development" : 2}, inplace = True)

# %%
# JobRole
mitarbeiter02.JobRole.replace({"Sales Executive" : 0, "Research Scientist" : 1, "Laboratory Technician" : 2, 
                              "Manufacturing Director" : 3, "Healthcare Representative" : 4, "Manager" : 5,
                              "Sales Representative" : 6, "Research Director" : 7, "Human Resources" : 8, 
                              }, inplace = True)

# %%
# MaritalStatus
mitarbeiter02.MaritalStatus.replace({"Single" : 0, "Divorced" : 1, "Married" : 2}, inplace = True)

# %%
# Overtime - Überstunden
mitarbeiter02.OverTime.replace({"No" : 0, "Yes" : 1}, inplace = True)

# %%
# Work_accident
mitarbeiter02.Work_accident.replace({"No" : 0, "Yes" : 1}, inplace = True)

# %%
# Ausbildung
mitarbeiter02.Higher_Education.replace({"12th" : 0, "Graduation" : 1, "Post-Graduation" : 2, "PHD" : 3}, 
                                       inplace = True)

# %%
# # Kündigungsgrund
mitarbeiter02.Status_of_leaving.replace({"Dept.Head" : 0, "Salary" : 1, "Work Environment" : 2, "Work Accident" : 3, 
                                         "Better Opportunity" : 4}, inplace = True)

# %%
# Arbeitsort
mitarbeiter02.Mode_of_work.replace({"WFH" : 0, "OFFICE" : 1}, inplace = True)

# %%
# Anwerbungsart
mitarbeiter02.Source_of_Hire.replace({"Recruiter" : 0, "Job Event" : 1, "Walk-in" : 2, "Job Portal" : 3}, 
                                       inplace = True)

# %%
# Jobart
mitarbeiter02.Job_mode.replace({"FullTime" : 0, "Contract" : 1, "Part Time" : 2}, inplace = True)

# %%
mitarbeiter02.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Higher_Education', 'Status_of_leaving',
#        'Mode_of_work', 'Leaves', 'Absenteeism', 'Work_accident',
#        'Source_of_Hire', 'Job_mode'],
#       dtype='object')

# %%
mitarbeiter01["JobSatisfaction"].value_counts()
# Out:
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64

# %%
mitarbeiter02.describe()
# Out:
#                Age    Attrition  BusinessTravel   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000
# mean     36.923810     0.161224        1.086395     1.610884
# std       9.135373     0.367863        0.532170     0.568893
# min      18.000000     0.000000        0.000000     0.000000
# 25%      30.000000     0.000000        1.000000     1.000000
# 50%      36.000000     0.000000        1.000000     2.000000
# 75%      43.000000     0.000000        1.000000     2.000000
# max      60.000000     1.000000        2.000000     2.000000
#
#        DistanceFromHome       Gender  JobInvolvement     JobLevel  \
# count       1470.000000  1470.000000     1470.000000  1470.000000
# mean           9.192517     0.600000        2.729932     2.063946
# std            8.106864     0.490065        0.711561     1.106940
# min            1.000000     0.000000        1.000000     1.000000
# 25%            2.000000     0.000000        2.000000     1.000000
# ...

# %% [markdown]
# # KORRELATIONEN

# %%
mitarbeiter02.corr(numeric_only=True)
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.159205       -0.011807    0.007652
# Attrition               -0.159205   1.000000        0.127006   -0.077351
# BusinessTravel          -0.011807   0.127006        1.000000    0.005436
# Department               0.007652  -0.077351        0.005436    1.000000
# DistanceFromHome        -0.001686   0.077924       -0.009696   -0.002196
# Gender                  -0.036311   0.029453       -0.044896    0.000488
# JobInvolvement           0.029820  -0.130016        0.029300    0.017693
# JobLevel                 0.509604  -0.169105       -0.011696   -0.088018
# JobRole                  0.159715  -0.027930        0.023537   -0.084779
# JobSatisfaction         -0.004892  -0.103481        0.008666    0.006231
# MaritalStatus            0.111831  -0.145985       -0.011068   -0.021989
# MonthlyIncome            0.497855  -0.159840       -0.013450   -0.056573
# ...

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(mitarbeiter02.iloc[::, :9].corr(numeric_only=True), annot=True, fmt=".2f", cmap="rainbow" )
# Out:
# <Axes: >

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(mitarbeiter02.iloc[::, 10:18].corr(numeric_only=True), annot=True, fmt=".2f", cmap="rainbow" )
plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource11.png')

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(mitarbeiter02.iloc[::, 19:27].corr(numeric_only=True), annot=True, fmt=".2f", cmap="rainbow" )
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(mitarbeiter02.iloc[::, ::].corr(numeric_only=True), annot=True, fmt=".1f", linewidths=0.2, cmap="rainbow")
plt.title("KORRELATIONEN VON ALLEN FEATURES\n")
#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource11.png')
# Out:
# Text(0.5, 1.0, 'KORRELATIONEN VON ALLEN FEATURES\n')

# %%
corr = mitarbeiter02.corr()[['Attrition']]. round(2).sort_values(by = ['Attrition'], 
       ascending = False).drop(['Attrition'])

# %%
# für Tableau
corr = corr.reset_index()
corr
# corr.to_csv("cor dataset Attrition.csv",index=False)
# Out:
#                       index  Attrition
# 0                  OverTime       0.25
# 1            BusinessTravel       0.13
# 2          DistanceFromHome       0.08
# 3        NumCompaniesWorked       0.04
# 4                    Gender       0.03
# 5            Source_of_Hire       0.01
# 6             Work_accident       0.01
# 7              Mode_of_work       0.01
# 8         Status_of_leaving       0.01
# 9          Higher_Education      -0.00
# 10        PerformanceRating       0.00
# 11        PercentSalaryHike      -0.01
# 12  YearsSinceLastPromotion      -0.03
# 13                  JobRole      -0.03
# 14                   Leaves      -0.04
# 15              Absenteeism      -0.04
# 16                 Job_mode      -0.04
# 17    TrainingTimesLastYear      -0.06
# 18               Department      -0.08
# 19          JobSatisfaction      -0.10
# 20           YearsAtCompany      -0.13
# 21           JobInvolvement      -0.13
# 22            MaritalStatus      -0.15
# ...

# %%
#WICHTIGE KORRELATIONEN:

#KORRELATION 1.0:

#* MonthlyIncome - JobLevel

#KORRELATION 0.8:

#* YearsAtCompany    - YearsWithCurrentManager
#* PerformanceRating - PercentSalaryHike
#* MonthlyIncome     - TotalWorkingYears
#* JobLevel          - TotalWorkingYears

#KORRELATION 0.7:

#* Age - TotalWorkingYears

#KORRELATION 0.6:

#* YearsAtCompany    - YearsSinceLastPromotion
#* TotalWorkingYears - YearsAtCompany

#HÖCHSTE KORRELATIONEN MIT DEM LABEL ATTRITION:
    
#* OverTime                  -   Attrition     0.25
#* BusinessTravel            -   Attrition     0.13
#* DistanceFromHome          -   Attriton      0.08
#* JobLevel                  -   Attrition    -0.17
#* TotalWorkingYears         -   Attrition    -0,17
#* Age                       -   Attrition    -0.16
#* YearsWithCurrentManager   -   Attrition    -0.16
#* MaritalStatus             -   Attrition    -0.15

# %% [markdown]
# # WICHTIGE KORRELATIONEN:
#
# KORRELATION 1.0:
#
# * MonthlyIncome - JobLevel
#
# KORRELATION 0.8:
#
# * YearsAtCompany    - YearsWithCurrentManager
# * PerformanceRating - PercentSalaryHike
# * MonthlyIncome     - TotalWorkingYears
# * JobLevel          - TotalWorkingYears
#
#
# KORRELATION 0.7:
#
# * Age - TotalWorkingYears
#
# KORRELATION 0.6:
#
# * YearsAtCompany    - YearsSinceLastPromotion
# * TotalWorkingYears - YearsAtCompany
#
# HÖCHSTE KORRELATIONEN MIT DEM LABEL ATTRITION:
#
# * OverTime                  -   Attrition     0.25
# * BusinessTravel            -   Attrition     0.13
# * DistanceFromHome          -   Attriton      0.08
# * JobLevel                  -   Attrition    -0.17
# * TotalWorkingYears         -   Attrition    -0,17
# * Age                       -   Attrition    -0.16
# * YearsWithCurrentManager   -   Attrition    -0.16
# * MaritalStatus             -   Attrition    -0.15

# %% [markdown]
# # VISUALISIERUNGEN

# %%
total = mitarbeiter01["Gender"].value_counts()

my_circle = plt.Circle( (0,0), 0.7, color='white') 

plt.figure(figsize=(5,5))

plt.pie(total.values, labels = total.index, autopct='%1.2f%%')
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.title("Geschlechterverteilung in %")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource04.png')
# Out:
# Text(0.5, 1.0, 'Geschlechterverteilung in %')

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=mitarbeiter01, x="Gender", hue="Attrition", multiple="stack", bins=5, palette="viridis")
plt.xlabel("Geschlecht")
plt.ylabel("Kündigung")
plt.title("Kündigung Frauen/Männer")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource05.png')
# Out:
# Text(0.5, 1.0, 'Kündigung Frauen/Männer')

# %%
plt.figure(figsize=(4,3))
sns.boxplot(data=mitarbeiter01, x="Gender", y="Age")
plt.xlabel("Geschlecht")
plt.ylabel("Alter")
plt.title("Alter Frauen/Männer")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource06.png')
# Out:
# Text(0.5, 1.0, 'Alter Frauen/Männer')

# %%
plt.figure(figsize=(20,3))

sns.violinplot(x=mitarbeiter01["Age"],inner="stick", color = "gold")
plt.xlabel("Age")
plt.title("ALTERSVERTEILUNG GESAMT")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource07.png')
# Out:
# Text(0.5, 1.0, 'ALTERSVERTEILUNG GESAMT')

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=mitarbeiter01, x="Age", hue="Attrition", multiple="stack", bins=5, palette="crest")
plt.xlabel("Alter")
plt.ylabel("Kündigung")
plt.title("Alter in Bezug auf Kündigung")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource08.png')
# Out:
# Text(0.5, 1.0, 'Alter in Bezug auf Kündigung')

# %%
plt.figure(figsize=(4, 3))
sns.countplot(mitarbeiter01, x="OverTime", hue="Attrition", palette="viridis")
plt.xlabel("Überstunden")
plt.ylabel("Kündigung")
plt.title("Kündigung in Verbindung mit Überstunden")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource09.png')
# Out:
# Text(0.5, 1.0, 'Kündigung in Verbindung mit Überstunden')

# %%
# Export plots
# plt.savefig(plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource01.png');

# %%
fig, axes = plt.subplots(1, 3,  figsize=(10, 3))

sns.countplot(data=mitarbeiter01, x="Gender", hue='Attrition', palette='Set1',ax=axes[0])
axes[0].set_title("Geschlecht und Kündigung")
sns.countplot(data=mitarbeiter01, x="OverTime", hue='Attrition', palette='hls', ax=axes[1])
axes[1].set_title('Überstunden und Kündigung')
sns.countplot(data=mitarbeiter01, x="MaritalStatus", hue='Attrition', palette='Set2', ax=axes[2])
axes[2].set_title('Status und Kündigung')

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource01.png')
# Out:
# Text(0.5, 1.0, 'Status und Kündigung')

# %%
fig, axes = plt.subplots(1, 3,  figsize=(10, 3))

a = sns.countplot(data=mitarbeiter01, x="JobRole", hue='Attrition', palette='hls', ax=axes[0])
axes[0].set_title("Jobart und Kündigung")
a.set_xticklabels(a.get_xticklabels(), rotation=80)
b = sns.countplot(data=mitarbeiter01, x="JobLevel", hue='Attrition', palette='Set2', ax=axes[1])
axes[1].set_title('Joblevel und Kündigung')
b.set_xticklabels(b.get_xticklabels(), rotation=45)
c=sns.countplot(data=mitarbeiter01, x="Work_accident", hue='Attrition', palette='Set1', ax=axes[2])
axes[2].set_title('Arbeitsunfall und Kündigung')
c.set_xticklabels(c.get_xticklabels(), rotation=45)

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource02.png')
# Out:
# [Text(0, 0, 'No'), Text(1, 0, 'Yes')]

# %%
fig, axes = plt.subplots(1, 3,  figsize=(10, 3))

a = sns.countplot(data=mitarbeiter01, x="BusinessTravel", hue='Attrition', palette='hls', ax=axes[0])
axes[0].set_title("Geschäftsreisen und Kündigung")
a.set_xticklabels(a.get_xticklabels(), rotation=80)
b = sns.countplot(data=mitarbeiter01, x="Job_mode", hue='Attrition', palette='Set1', ax=axes[1])
axes[1].set_title('Vertragsart und Kündigung')
b.set_xticklabels(b.get_xticklabels(), rotation=80)
c=sns.countplot(data=mitarbeiter01, x="Department", hue='Attrition', palette='Set2', ax=axes[2])
axes[2].set_title('Abteilung und Kündigung')
c.set_xticklabels(c.get_xticklabels(), rotation=80)

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource03.png')
# Out:
# [Text(0, 0, 'Research & Development'),
#  Text(1, 0, 'Sales'),
#  Text(2, 0, 'Human Resources')]

# %% [markdown]
# # Supervised Learning

# %%
# alle features

# features mit höchsten Korrelationen

# features mit niedrigen Korrelationen

# reduziert mit PCA

# %% [markdown]
# # alle features:

# %%
X01 = mitarbeiter02.drop(['Attrition'], axis=1)
y01 = mitarbeiter02['Attrition']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X01, y01, test_size = 0.20, random_state = 33)

# %%
# Standardscaler für Streuung und Varianz

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# Algorithmen
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

log = LogisticRegression()
knc = KNeighborsClassifier()
svc = SVC()
nab = GaussianNB()
rfc = RandomForestClassifier()

# %%
# Ellbow method für KN um die geeignete Anzahl von Nachbarn auszuwählen --> jedes k durchprobieren

fehler = []

for k in range(1, 10):                                                    
    knc = KNeighborsClassifier(n_neighbors = k)        
    knc.fit(X_train, y_train)
    predictions_k = knc.predict(X_test)
    fehler.append(np.mean(predictions_k != y_test))     

plt.figure(figsize=(6, 4))
plt.plot(range(1, 10), fehler, marker = "x")     
plt.xlabel('n_neighbors')
plt.ylabel('Fehlerwert')
plt.title("Ellbow method 01")
#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource10.png')
# Out:
# Text(0.5, 1.0, 'Ellbow method 01')

# %%
# beste Parameter für SVC

from sklearn.model_selection import GridSearchCV

# dictionary mit Werten für C und gamma
hyperparameter = {"C" : [0.1, 1, 10, 100, 1000], "gamma" : [1, 0.1, 0.01, 0.001, 0.0001]}

grid01 = GridSearchCV(SVC(), hyperparameter, refit = True)
grid01.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001]})

# %%
grid01.best_params_
# Out:
# {'C': 1000, 'gamma': 0.0001}

# %%
# TRAINIEREN

log = LogisticRegression().fit(X_train, y_train)
knc = KNeighborsClassifier(n_neighbors = 6).fit(X_train, y_train)              # bester Wert 6
svc = SVC(C=1000, gamma=0.0001).fit(X_train, y_train)
nab = GaussianNB().fit(X_train, y_train)
rfc = RandomForestClassifier(random_state = 33, n_estimators = 1000).fit(X_train, y_train)

# %%
# VORHERSAGEN

pred_log = log.predict(X_test)
pred_knc = knc.predict(X_test)
pred_svc = svc.predict(X_test)
pred_nab = nab.predict(X_test)
pred_rfc = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, confusion_matrix, classification_report

# %%
# REPORTS

print("Genauigkeit LogReg: {:.2f}%".format((accuracy_score(y_test, pred_log)*100)))
print("Genauigkeit KNN: {:.2f}%".format((accuracy_score(y_test, pred_knc)*100)))        # verschiedene k ausprobiert  
print("Genauigkeit SVC: {:.2f}%".format((accuracy_score(y_test, pred_svc)*100)))                      
print("Genauigkeit NAIVE: {:.2f}%".format((accuracy_score(y_test, pred_nab)*100)))
print("Genauigkeit Random: {:.2f}%".format((accuracy_score(y_test, pred_rfc)*100)))
# Out:
# Genauigkeit LogReg: 91.16%
# Genauigkeit KNN: 90.48%
# Genauigkeit SVC: 91.50%
# Genauigkeit NAIVE: 84.01%
# Genauigkeit Random: 89.12%

# %%
models = [log, knc, svc, nab, rfc]
model_names = ["LogisticRegression","KNeighborsClassifier", "SVC", "NaiveBayes","RandomForestClassifier",]


# for- Schleife bauen um über alle Algorithmen zu iterieren mit dazugehörigen reports

accuracy_scores = []
precision_scores = []
recall_scores = []
error_rate = []

for i, m in enumerate(models):
    y_pred = m.predict(X_test)                               # Vorhersagen für alle Algorithmen
    conf_matrix = confusion_matrix(y_test, y_pred)           # confusion matrix
    
    print("Modell: ", model_names[i], "\n")
    print("Classification Report: ", classification_report(y_test, y_pred), "\n")
    print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred), "\n")
    
    # nur für Teil um confusion matrix in _Tabelle zu erstellen mit Dataframe
    true_positive = conf_matrix[0,0]
    true_negative = conf_matrix[1,1]
    false_positive = conf_matrix[0,1]
    false_negative =  conf_matrix[1,0]
    
    #TP: Als Klasse 0 vorhergesagt, tatsächlich Klasse 0
    #TN: Als Klasse 1 vorhergesagt, tatsächlich Klasse 1
    #FP: Als Klasse 0 vorhergesagt, tatsächlich Klasse 1
    #FN: Als Klasse 1 vorhergeasgt, tatsächlich Klasse 0
    
    total = true_positive + true_negative + false_positive + false_negative  
    
    accuracy = (true_positive + true_negative) / total                 # accuracy berechnen usw.....
    precision = true_positive / (true_positive + false_positive)
    recall = true_positive / (true_positive + false_negative)
    error = (false_positive + false_negative) / total
    
    
    accuracy_scores.append(accuracy.round(2)*100)
    precision_scores.append(precision.round(2))
    recall_scores.append(recall.round(2))
    error_rate.append(error.round(2))

# Dataframe erstellen:

ergebnisse_df = pd.DataFrame(list(zip(accuracy_scores, precision_scores, recall_scores, error_rate)), 
                            index = model_names, columns = ["accuracy", "precision", "recall", "error"])

ergebnisse_df
# Out:
# Modell:  LogisticRegression
#
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       261
#            1       0.64      0.48      0.55        33
#
#     accuracy                           0.91       294
#    macro avg       0.79      0.73      0.75       294
# weighted avg       0.90      0.91      0.91       294
#
#
# Confusion Matrix:
#  [[252   9]
#  [ 17  16]]
#
# Modell:  KNeighborsClassifier
#
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       261
#            1       0.78      0.21      0.33        33
#
#     accuracy                           0.90       294
#    macro avg       0.84      0.60      0.64       294
# weighted avg       0.89      0.90      0.88       294
#
#
# Confusion Matrix:
#  [[259   2]
#  [ 26   7]]
#
# Modell:  SVC
#
# Classification Report:                precision    recall  f1-score   support
# ...

# %%
matrix_log = confusion_matrix(y_test, pred_log)
matrix_knc = confusion_matrix(y_test, pred_knc)
matrix_svc = confusion_matrix(y_test, pred_svc)
matrix_nab = confusion_matrix(y_test, pred_nab)
matrix_rfc = confusion_matrix(y_test, pred_rfc)

fig, axes = plt.subplots(1, 5, figsize=(13, 3))


sns.heatmap(matrix_log, annot=True, cbar = False,  cmap="crest", fmt = ".0f", ax=axes[0])
axes[0].set_title("LogReg01")
sns.heatmap(matrix_knc, annot=True, cbar = False,  cmap="rainbow", fmt = ".0f", ax=axes[1])
axes[1].set_title("KNNeighbor01")
sns.heatmap(matrix_svc, annot=True, cbar = False,  cmap="viridis", fmt = ".0f", ax=axes[2])
axes[2].set_title("SVC01")
sns.heatmap(matrix_nab, annot=True, cbar = False,  cmap="coolwarm", fmt = ".0f", ax=axes[3])
axes[3].set_title("Naive Bayes01")
sns.heatmap(matrix_rfc, annot=True, cbar = False,  cmap="Blues_r", fmt = ".0f", ax=axes[4])
axes[4].set_title("RandomForest01")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource12.png')
# Out:
# Text(0.5, 1.0, 'RandomForest01')

# %% [markdown]
# # features mit höchsten Korrelationen:

# %%
X02 = mitarbeiter02[["OverTime", "BusinessTravel", "JobSatisfaction", "YearsAtCompany", "JobInvolvement",
                    "MaritalStatus", "YearsWithCurrManager", "MonthlyIncome", "Age", "TotalWorkingYears", "JobLevel"]]
y02 = mitarbeiter02["Attrition"]

# %%
X02.shape
# Out:
# (1470, 11)

# %%
from sklearn.model_selection import train_test_split

X_train02, X_test02, y_train02, y_test02 = train_test_split(X02, y02, test_size = 0.20, random_state = 33)

# %%
# Standardscaler für Streuung und Varianz

X_train02 = scaler.fit_transform(X_train02)
X_test02 = scaler.fit_transform(X_test02)

# %%
# Algorithmen
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

log02 = LogisticRegression()
knc02 = KNeighborsClassifier()
svc02 = SVC()
nab02 = GaussianNB()
rfc02 = RandomForestClassifier()

# %%
# Ellbow method für KN um die geeignete Anzahl von Nachbarn auszuwählen --> jedes k durchprobieren

fehler02 = []

for k in range(1, 10):                                                    
    knc02 = KNeighborsClassifier(n_neighbors = k)        
    knc02.fit(X_train02, y_train02)
    predictions_k02 = knc02.predict(X_test02)
    fehler02.append(np.mean(predictions_k02 != y_test02))     

plt.figure(figsize=(6, 4))
plt.plot(range(1, 10), fehler02, marker = "x")     
plt.xlabel('n_neighbors')
plt.ylabel('Fehlerwert')         
plt.title("Ellbow method 02")
#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource13.png')
# Out:
# Text(0.5, 1.0, 'Ellbow method 02')

# %%
# beste Parameter für SVC

hyperparameter = {"C" : [0.1, 1, 10, 100, 1000], "gamma" : [1, 0.1, 0.01, 0.001, 0.0001]}

grid02 = GridSearchCV(SVC(), hyperparameter, refit = True)
grid02.fit(X_train02, y_train02)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001]})

# %%
grid02.best_params_
# Out:
# {'C': 10, 'gamma': 0.01}

# %%
# TRAINIEREN

log02 = LogisticRegression().fit(X_train02, y_train02)
knc02 = KNeighborsClassifier(n_neighbors = 6).fit(X_train02, y_train02)             
svc02 = SVC(C=10, gamma=0.01).fit(X_train02, y_train02)
nab02 = GaussianNB().fit(X_train02, y_train02)
rfc02 = RandomForestClassifier(random_state = 33, n_estimators = 1000).fit(X_train02, y_train02)

# %%
# VORHERSAGEN

pred_log02 = log02.predict(X_test02)
pred_knc02 = knc02.predict(X_test02)
pred_svc02 = svc02.predict(X_test02)
pred_nab02 = nab02.predict(X_test02)
pred_rfc02 = rfc02.predict(X_test02)

# %%
# REPORTS
print("ALLE FEATURES:\n")
print("Genauigkeit LogReg: {:>12.2f}%".format((accuracy_score(y_test, pred_log)*100)))
print("Genauigkeit KNN   : {:>12.2f}%".format((accuracy_score(y_test, pred_knc)*100)))   
print("Genauigkeit SVC   : {:>12.2f}%".format((accuracy_score(y_test, pred_svc)*100)))                      
print("Genauigkeit NAIVE : {:>12.2f}%".format((accuracy_score(y_test, pred_nab)*100)))
print("Genauigkeit Random: {:>12.2f}%\n".format((accuracy_score(y_test, pred_rfc)*100)))      

print("FEATURES MIT HÖCHSTEN KORRELATIONEN:\n")
print("Genauigkeit LogReg02: {:>10.2f}%".format((accuracy_score(y_test02, pred_log02)*100)))
print("Genauigkeit KNN02   : {:>10.2f}%".format((accuracy_score(y_test02, pred_knc02)*100)))    
print("Genauigkeit SVC02   : {:>10.2f}%".format((accuracy_score(y_test02, pred_svc02)*100)))                      
print("Genauigkeit NAIVE02 : {:>10.2f}%".format((accuracy_score(y_test02, pred_nab02)*100)))
print("Genauigkeit Random02: {:>10.2f}%".format((accuracy_score(y_test02, pred_rfc02)*100)))
# Out:
# ALLE FEATURES:
#
# Genauigkeit LogReg:        91.16%
# Genauigkeit KNN   :        90.48%
# Genauigkeit SVC   :        91.50%
# Genauigkeit NAIVE :        84.01%
# Genauigkeit Random:        89.12%
#
# FEATURES MIT HÖCHSTEN KORRELATIONEN:
#
# Genauigkeit LogReg02:      91.50%
# Genauigkeit KNN02   :      89.46%
# Genauigkeit SVC02   :      90.14%
# Genauigkeit NAIVE02 :      82.31%
# Genauigkeit Random02:      89.12%

# %%
matrix_log02 = confusion_matrix(y_test02, pred_log02)
matrix_knc02 = confusion_matrix(y_test02, pred_knc02)
matrix_svc02 = confusion_matrix(y_test02, pred_svc02)
matrix_nab02 = confusion_matrix(y_test02, pred_nab02)
matrix_rfc02 = confusion_matrix(y_test02, pred_rfc02)

fig, axes = plt.subplots(1, 5, figsize=(13, 3))

sns.heatmap(matrix_log02, annot=True, cbar = False,  cmap="crest", fmt = ".0f", ax=axes[0])
axes[0].set_title("LogReg02")
sns.heatmap(matrix_knc02, annot=True, cbar = False,  cmap="rainbow", fmt = ".0f", ax=axes[1])
axes[1].set_title("KNNeighbor02")
sns.heatmap(matrix_svc02, annot=True, cbar = False,  cmap="viridis", fmt = ".0f", ax=axes[2])
axes[2].set_title("SVC02")
sns.heatmap(matrix_nab02, annot=True, cbar = False,  cmap="coolwarm", fmt = ".0f", ax=axes[3])
axes[3].set_title("Naive Bayes02")
sns.heatmap(matrix_rfc02, annot=True, cbar = False,  cmap="Blues_r", fmt = ".0f", ax=axes[4])
axes[4].set_title("RandomForest02")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource15.png')
# Out:
# Text(0.5, 1.0, 'RandomForest02')

# %% [markdown]
# # features mit geringsten Korrelationen:

# %%
X03 = mitarbeiter02[["DistanceFromHome", "NumCompaniesWorked", "Gender", "Source_of_Hire", "Work_accident",
                    "Mode_of_work", "Status_of_leaving", "Higher_Education", "PerformanceRating", "PercentSalaryHike",
                     "YearsSinceLastPromotion", "JobRole", "Leaves", "Absenteeism", "Job_mode",
                     "TrainingTimesLastYear", "Department"]]
y03 = mitarbeiter02["Attrition"]

# %%
X03.shape
# Out:
# (1470, 17)

# %%
X_train03, X_test03, y_train03, y_test03 = train_test_split(X03, y03, test_size = 0.20, random_state = 33)

# %%
# Standardscaler für Streuung und Varianz

X_train03 = scaler.fit_transform(X_train03)
X_test03 = scaler.fit_transform(X_test03)

# %%
# Algorithmen
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

log03 = LogisticRegression()
knc03 = KNeighborsClassifier()
svc03 = SVC()
nab03 = GaussianNB()
rfc03 = RandomForestClassifier()

# %%
# Ellbow method für KN um die geeignete Anzahl von Nachbarn auszuwählen --> jedes k durchprobieren

fehler03 = []

for k in range(1, 10):                                                    
    knc03 = KNeighborsClassifier(n_neighbors = k)        
    knc03.fit(X_train03, y_train03)
    predictions_k03 = knc03.predict(X_test03)
    fehler03.append(np.mean(predictions_k03 != y_test03))     

plt.figure(figsize=(6, 4))
plt.plot(range(1, 10), fehler03, marker = "x")     
plt.xlabel('n_neighbors')
plt.ylabel('Fehlerwert')         
plt.title("Ellbow method 03")
#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource14.png')
# Out:
# Text(0.5, 1.0, 'Ellbow method 03')

# %%
# beste Parameter für SVC

hyperparameter = {"C" : [0.1, 1, 10, 100, 1000], "gamma" : [1, 0.1, 0.01, 0.001, 0.0001]}

grid03 = GridSearchCV(SVC(), hyperparameter, refit = True)
grid03.fit(X_train03, y_train03)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001]})

# %%
grid03.best_params_
# Out:
# {'C': 0.1, 'gamma': 1}

# %%
# TRAINIEREN

log03 = LogisticRegression().fit(X_train03, y_train03)
knc03 = KNeighborsClassifier(n_neighbors = 6).fit(X_train03, y_train03)             
svc03 = SVC(C=0.1, gamma=1).fit(X_train03, y_train03)
nab03 = GaussianNB().fit(X_train03, y_train03)
rfc03 = RandomForestClassifier(random_state = 33, n_estimators = 1000).fit(X_train03, y_train03)

# %%
# VORHERSAGEN

pred_log03 = log03.predict(X_test03)
pred_knc03 = knc03.predict(X_test03)
pred_svc03 = svc03.predict(X_test03)
pred_nab03 = nab03.predict(X_test03)
pred_rfc03 = rfc03.predict(X_test03)

# %%
# REPORTS
print("ALLE FEATURES:\n")
print("Genauigkeit LogReg01: {:>10.2f}%".format((accuracy_score(y_test, pred_log)*100)))
print("Genauigkeit KNN01   : {:>10.2f}%".format((accuracy_score(y_test, pred_knc)*100)))   
print("Genauigkeit SVC01   : {:>10.2f}%".format((accuracy_score(y_test, pred_svc)*100)))                      
print("Genauigkeit NAIVE01 : {:>10.2f}%".format((accuracy_score(y_test, pred_nab)*100)))
print("Genauigkeit Random01: {:>10.2f}%\n".format((accuracy_score(y_test, pred_rfc)*100)))      

print("FEATURES MIT HÖCHSTEN KORRELATIONEN:\n")
print("Genauigkeit LogReg02: {:>10.2f}%".format((accuracy_score(y_test02, pred_log02)*100)))
print("Genauigkeit KNN02   : {:>10.2f}%".format((accuracy_score(y_test02, pred_knc02)*100)))    
print("Genauigkeit SVC02   : {:>10.2f}%".format((accuracy_score(y_test02, pred_svc02)*100)))                      
print("Genauigkeit NAIVE02 : {:>10.2f}%".format((accuracy_score(y_test02, pred_nab02)*100)))
print("Genauigkeit Random02: {:>10.2f}%\n".format((accuracy_score(y_test02, pred_rfc02)*100)))

print("FEATURES MIT GERINGSTEN KORRELATIONEN:\n")
print("Genauigkeit LogReg03: {:>10.2f}%".format((accuracy_score(y_test03, pred_log03)*100)))
print("Genauigkeit KNN03   : {:>10.2f}%".format((accuracy_score(y_test03, pred_knc03)*100)))   
print("Genauigkeit SVC03   : {:>10.2f}%".format((accuracy_score(y_test03, pred_svc03)*100)))                      
print("Genauigkeit NAIVE03 : {:>10.2f}%".format((accuracy_score(y_test03, pred_nab03)*100)))
print("Genauigkeit Random03: {:>10.2f}%\n".format((accuracy_score(y_test03, pred_rfc03)*100)))
# Out:
# ALLE FEATURES:
#
# Genauigkeit LogReg01:      91.16%
# Genauigkeit KNN01   :      90.48%
# Genauigkeit SVC01   :      91.50%
# Genauigkeit NAIVE01 :      84.01%
# Genauigkeit Random01:      89.12%
#
# FEATURES MIT HÖCHSTEN KORRELATIONEN:
#
# Genauigkeit LogReg02:      91.50%
# Genauigkeit KNN02   :      89.46%
# Genauigkeit SVC02   :      90.14%
# Genauigkeit NAIVE02 :      82.31%
# Genauigkeit Random02:      89.12%
#
# FEATURES MIT GERINGSTEN KORRELATIONEN:
#
# Genauigkeit LogReg03:      88.78%
# Genauigkeit KNN03   :      88.10%
# Genauigkeit SVC03   :      88.78%
# Genauigkeit NAIVE03 :      88.78%
# Genauigkeit Random03:      88.78%

# %%
matrix_log03 = confusion_matrix(y_test03, pred_log03)
matrix_knc03 = confusion_matrix(y_test03, pred_knc03)
matrix_svc03 = confusion_matrix(y_test03, pred_svc03)
matrix_nab03 = confusion_matrix(y_test03, pred_nab03)
matrix_rfc03 = confusion_matrix(y_test03, pred_rfc03)

fig, axes = plt.subplots(1, 5, figsize=(13, 3))

sns.heatmap(matrix_log03, annot=True, cbar = False,  cmap="crest", fmt = ".0f", ax=axes[0])
axes[0].set_title("LogReg03")
sns.heatmap(matrix_knc03, annot=True, cbar = False,  cmap="rainbow", fmt = ".0f", ax=axes[1])
axes[1].set_title("KNNeighbor03")
sns.heatmap(matrix_svc03, annot=True, cbar = False,  cmap="viridis", fmt = ".0f", ax=axes[2])
axes[2].set_title("SVC03")
sns.heatmap(matrix_nab03, annot=True, cbar = False,  cmap="coolwarm", fmt = ".0f", ax=axes[3])
axes[3].set_title("Naive Bayes03")
sns.heatmap(matrix_rfc03, annot=True, cbar = False,  cmap="Blues_r", fmt = ".0f", ax=axes[4])
axes[4].set_title("RandomForest03")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource15.png')
# Out:
# Text(0.5, 1.0, 'RandomForest03')

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# # PCA

# %%
# Erhaltene Information in Abhängigkeit der Principal Components überprüfen:

from sklearn.decomposition import PCA

plt.figure(figsize=(5, 3)) 

pca_check = PCA(n_components=29, random_state = 33)            
pca_check.fit(mitarbeiter02)                                             
plt.plot(np.cumsum(pca_check.explained_variance_ratio_))
plt.xlabel("Number of components")
plt.ylabel("Explained variance")
plt.title("Principal Components erhaltene Informationen")
plt.show()
#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource17.png')

# %%
# Erste Komponente  enthält nahezu 100 % der Informationen

for i,value in enumerate(pca_check.explained_variance_ratio_):
    print(f"{i+1}. Principal Component erklärt {value*100:.4f}% der Varianz ")
# Out:
# 1. Principal Component erklärt 99.9989% der Varianz
# 2. Principal Component erklärt 0.0003% der Varianz
# 3. Principal Component erklärt 0.0003% der Varianz
# 4. Principal Component erklärt 0.0002% der Varianz
# 5. Principal Component erklärt 0.0001% der Varianz
# 6. Principal Component erklärt 0.0001% der Varianz
# 7. Principal Component erklärt 0.0000% der Varianz
# 8. Principal Component erklärt 0.0000% der Varianz
# 9. Principal Component erklärt 0.0000% der Varianz
# 10. Principal Component erklärt 0.0000% der Varianz
# 11. Principal Component erklärt 0.0000% der Varianz
# 12. Principal Component erklärt 0.0000% der Varianz
# 13. Principal Component erklärt 0.0000% der Varianz
# 14. Principal Component erklärt 0.0000% der Varianz
# 15. Principal Component erklärt 0.0000% der Varianz
# 16. Principal Component erklärt 0.0000% der Varianz
# 17. Principal Component erklärt 0.0000% der Varianz
# 18. Principal Component erklärt 0.0000% der Varianz
# ...

# %%
X04 = mitarbeiter02.drop(['Attrition'], axis=1)

# %%
#Standardscaler:

scaled_X04 = scaler.fit_transform(X04)

# %%
# PCA mit 1 Komponente

pca = PCA(n_components=1, random_state=33)

# %%
# PCA: trainieren und transformieren:

x_pca = pca.fit_transform(scaled_X04)

# %%
x_pca.shape
# Out:
# (1470, 1)

# %%
# Dataframe mit pca.components_

df_pastpca = pd.DataFrame(pca.components_, columns = mitarbeiter02.columns.drop("Attrition"))
df_pastpca
# Out:
#         Age  BusinessTravel  Department  DistanceFromHome    Gender  \
# 0  0.310182       -0.002029   -0.026538         -0.000324 -0.029104
#
#    JobInvolvement  JobLevel   JobRole  JobSatisfaction  MaritalStatus  ...  \
# 0       -0.003223  0.422649  0.165994         -0.01221        0.06046  ...
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Higher_Education  \
# 0                 0.286822              0.306687         -0.005525
#
#    Status_of_leaving  Mode_of_work    Leaves  Absenteeism  Work_accident  \
# 0           0.011803     -0.001038  0.017653    -0.014528       0.019729
#
#    Source_of_Hire  Job_mode
# 0        0.003412  0.025568
#
# [1 rows x 28 columns]

# %%
# Visualisierung einzelner features zu unterschiedlichen Gewichtungen mit max. Informationen

plt.figure(figsize=(12, 3))             
sns.heatmap(df_pastpca, cmap="rainbow")
plt.title("Gewichtungen Principal Components")
#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource18.png')
# Out:
# Text(0.5, 1.0, 'Gewichtungen Principal Components')

# %%
# Visualisierung bei 2 Komponenten ob gut unterscheidbar
#plt.figure(figsize=(5, 3)) 
#sns.scatterplot(x = x_pca[:, 0], y = x_pca[:, 1], hue = mitarbeiter02["Attrition"], palette = "crest")

# %% [markdown]
# # PCA mit Algorithmen durchlaufen lassen

# %%
X04 = x_pca
y04 = mitarbeiter02["Attrition"]

# %%
X_train04, X_test04, y_train04, y_test04 = train_test_split(X04, y04, test_size = 0.20, random_state = 33)

# %%
# Algorithmen

log04 = LogisticRegression()
knc04 = KNeighborsClassifier()
svc04 = SVC()
nab04 = GaussianNB()
rfc04 = RandomForestClassifier()

# %%
# Ellbow method für KN um die geeignete Anzahl von Nachbarn auszuwählen --> jedes k durchprobieren

fehler04 = []

for k in range(1, 10):                                                    
    knc04 = KNeighborsClassifier(n_neighbors = k)        
    knc04.fit(X_train04, y_train04)
    predictions_k04 = knc04.predict(X_test04)
    fehler04.append(np.mean(predictions_k04 != y_test04))     

plt.figure(figsize=(6, 4))
plt.plot(range(1, 10), fehler04, marker = "x")     
plt.xlabel('n_neighbors')
plt.ylabel('Fehlerwert')         
plt.title("Ellbow method 04")
#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource15.png')
# Out:
# Text(0.5, 1.0, 'Ellbow method 04')

# %%
# beste Parameter für SVC

hyperparameter = {"C" : [0.1, 1, 10, 100, 1000], "gamma" : [1, 0.1, 0.01, 0.001, 0.0001]}

grid04 = GridSearchCV(SVC(), hyperparameter, refit = True)
grid04.fit(X_train04, y_train04)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001]})

# %%
grid04.best_params_
# Out:
# {'C': 100, 'gamma': 1}

# %%
# TRAINIEREN

log04 = LogisticRegression().fit(X_train04, y_train04)
knc04 = KNeighborsClassifier(n_neighbors = 6).fit(X_train04, y_train04)             
svc04 = SVC(C=100, gamma=1).fit(X_train04, y_train04)
nab04 = GaussianNB().fit(X_train04, y_train04)
rfc04 = RandomForestClassifier(random_state = 33, n_estimators = 1000).fit(X_train04, y_train04)

# %%
# VORHERSAGEN

pred_log04 = log04.predict(X_test04)
pred_knc04 = knc04.predict(X_test04)
pred_svc04 = svc04.predict(X_test04)
pred_nab04 = nab04.predict(X_test04)
pred_rfc04 = rfc04.predict(X_test04)

# %%
# REPORTS
print("ALLE FEATURES:\n")
print("Genauigkeit LogReg01: {:>10.2f}%".format((accuracy_score(y_test, pred_log)*100)))
print("Genauigkeit KNN01   : {:>10.2f}%".format((accuracy_score(y_test, pred_knc)*100)))   
print("Genauigkeit SVC01   : {:>10.2f}%".format((accuracy_score(y_test, pred_svc)*100)))                      
print("Genauigkeit NAIVE01 : {:>10.2f}%".format((accuracy_score(y_test, pred_nab)*100)))
print("Genauigkeit Random01: {:>10.2f}%\n".format((accuracy_score(y_test, pred_rfc)*100)))      

print("FEATURES MIT HÖCHSTEN KORRELATIONEN:\n")
print("Genauigkeit LogReg02: {:>10.2f}%".format((accuracy_score(y_test02, pred_log02)*100)))
print("Genauigkeit KNN02   : {:>10.2f}%".format((accuracy_score(y_test02, pred_knc02)*100)))    
print("Genauigkeit SVC02   : {:>10.2f}%".format((accuracy_score(y_test02, pred_svc02)*100)))                      
print("Genauigkeit NAIVE02 : {:>10.2f}%".format((accuracy_score(y_test02, pred_nab02)*100)))
print("Genauigkeit Random02: {:>10.2f}%\n".format((accuracy_score(y_test02, pred_rfc02)*100)))

print("FEATURES MIT GERINGSTEN KORRELATIONEN:\n")
print("Genauigkeit LogReg03: {:>10.2f}%".format((accuracy_score(y_test03, pred_log03)*100)))
print("Genauigkeit KNN03   : {:>10.2f}%".format((accuracy_score(y_test03, pred_knc03)*100)))   
print("Genauigkeit SVC03   : {:>10.2f}%".format((accuracy_score(y_test03, pred_svc03)*100)))                      
print("Genauigkeit NAIVE03 : {:>10.2f}%".format((accuracy_score(y_test03, pred_nab03)*100)))
print("Genauigkeit Random03: {:>10.2f}%\n".format((accuracy_score(y_test03, pred_rfc03)*100)))

print("FEATURES MIT PCA REDUZIERT:\n")
print("Genauigkeit LogReg04: {:>10.2f}%".format((accuracy_score(y_test04, pred_log04)*100)))
print("Genauigkeit KNN04   : {:>10.2f}%".format((accuracy_score(y_test04, pred_knc04)*100)))   
print("Genauigkeit SVC04   : {:>10.2f}%".format((accuracy_score(y_test04, pred_svc04)*100)))                      
print("Genauigkeit NAIVE04 : {:>10.2f}%".format((accuracy_score(y_test04, pred_nab04)*100)))
print("Genauigkeit Random04: {:>10.2f}%\n".format((accuracy_score(y_test04, pred_rfc04)*100)))
# Out:
# ALLE FEATURES:
#
# Genauigkeit LogReg01:      91.16%
# Genauigkeit KNN01   :      90.48%
# Genauigkeit SVC01   :      91.50%
# Genauigkeit NAIVE01 :      84.01%
# Genauigkeit Random01:      89.12%
#
# FEATURES MIT HÖCHSTEN KORRELATIONEN:
#
# Genauigkeit LogReg02:      91.50%
# Genauigkeit KNN02   :      89.46%
# Genauigkeit SVC02   :      90.14%
# Genauigkeit NAIVE02 :      82.31%
# Genauigkeit Random02:      89.12%
#
# FEATURES MIT GERINGSTEN KORRELATIONEN:
#
# Genauigkeit LogReg03:      88.78%
# Genauigkeit KNN03   :      88.10%
# Genauigkeit SVC03   :      88.78%
# Genauigkeit NAIVE03 :      88.78%
# Genauigkeit Random03:      88.78%
#
# FEATURES MIT PCA REDUZIERT:
#
# Genauigkeit LogReg04:      88.78%
# Genauigkeit KNN04   :      88.10%
# Genauigkeit SVC04   :      88.78%
# Genauigkeit NAIVE04 :      88.78%
# Genauigkeit Random04:      73.81%

# %%
matrix_log04 = confusion_matrix(y_test04, pred_log04)
matrix_knc04 = confusion_matrix(y_test04, pred_knc04)
matrix_svc04 = confusion_matrix(y_test04, pred_svc04)
matrix_nab04 = confusion_matrix(y_test04, pred_nab04)
matrix_rfc04 = confusion_matrix(y_test04, pred_rfc04)

fig, axes = plt.subplots(1, 5, figsize=(13, 3))

sns.heatmap(matrix_log04, annot=True, cbar = False,  cmap="crest", fmt = ".0f", ax=axes[0])
axes[0].set_title("LogReg04")
sns.heatmap(matrix_knc04, annot=True, cbar = False,  cmap="rainbow", fmt = ".0f", ax=axes[1])
axes[1].set_title("KNNeighbor04")
sns.heatmap(matrix_svc04, annot=True, cbar = False,  cmap="viridis", fmt = ".0f", ax=axes[2])
axes[2].set_title("SVC04")
sns.heatmap(matrix_nab04, annot=True, cbar = False,  cmap="coolwarm", fmt = ".0f", ax=axes[3])
axes[3].set_title("Naive Bayes04")
sns.heatmap(matrix_rfc04, annot=True, cbar = False,  cmap="Blues_r", fmt = ".0f", ax=axes[4])
axes[4].set_title("RandomForest04")

#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource19.png')
# Out:
# Text(0.5, 1.0, 'RandomForest04')

# %% [markdown]
# # K-Means auf einer Komponente(PCA) anwenden

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn.cluster import KMeans

# %%
x_pca.shape
# Out:
# (1470, 1)

# %%
# ellbow method K-Means

error = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=33)
    kmeans.fit(x_pca)
    error.append(kmeans.inertia_)

plt.figure(figsize=(5, 3))
plt.grid()
plt.plot(range(1, 11), error, "bo-")               # Knick ist bei 2 oder 3
plt.title("Ellbow method K-Means 1 Dimension")
#plt.savefig(r'C:\Users\Fujitsu\Documents\Data Science_Manu\Projekt\Human_ressource21.png')
# Out:
# Text(0.5, 1.0, 'Ellbow method K-Means 1 Dimension')

# %%
# Mit 2 Cluster passend zu Attrition:

km = KMeans(n_clusters=2, random_state=33)

# %%
# Trainieren und Vorhersage:

pred_km = km.fit_predict(x_pca)

# %%
# neues Label mit den vorhergesagten Clustern hinzufügen an mitarbeiter02

mitarbeiter02["Label_K_means"] = pred_km

# %%
# Visualisierung Cluster mit verschiedenen features scatterplot

fig, axes = plt.subplots(2, 3,  figsize=(13, 10))

sns.scatterplot(data=mitarbeiter02, x="MonthlyIncome", y="TotalWorkingYears", hue="Label_K_means", ax=axes[0,0])

sns.scatterplot(data=mitarbeiter02, x="JobLevel", y="TotalWorkingYears", hue="Label_K_means", ax=axes[0,1])
axes[0,1].set_title("ERKANNTE CLUSTER 01")

sns.scatterplot(data=mitarbeiter02, x="YearsAtCompany", y="YearsWithCurrManager", hue="Label_K_means", ax=axes[0,2])

sns.scatterplot(data=mitarbeiter02, x="PerformanceRating", y="PercentSalaryHike", hue="Label_K_means", ax=axes[1,0])

sns.scatterplot(data=mitarbeiter02, x="Age", y="TotalWorkingYears", hue="Label_K_means", ax=axes[1,1])
axes[1,1].set_title("ERKANNTE CLUSTER 02")

sns.scatterplot(data=mitarbeiter02, x="MonthlyIncome", y="JobLevel", hue="Label_K_means", ax=axes[1,2])
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='JobLevel'>

# %%
# Visualisierung Cluster mit verschiedenen features boxplot

fig, axes = plt.subplots(1, 2,  figsize=(7, 5))

sns.boxplot(data=mitarbeiter02.iloc[500:, ::], x="Label_K_means", y="TotalWorkingYears", hue="Gender", ax=axes[0])
axes[0].set_title("LABEL CLUSTER")

sns.boxplot(data=mitarbeiter02.iloc[500:, ::], x="Attrition", y="TotalWorkingYears", hue="Gender", ax=axes[1])
axes[1].set_title("LABEL ATTRITION")
# Out:
# Text(0.5, 1.0, 'LABEL ATTRITION')

# %%
# Visualisierung Cluster mit verschiedenen features boxplot

fig, axes = plt.subplots(1, 2,  figsize=(7, 5))

sns.boxplot(data=mitarbeiter02, x="Label_K_means", y="Age", hue="Gender", ax=axes[0])
axes[0].set_title("LABEL CLUSTER")

sns.boxplot(data=mitarbeiter02, x="Attrition", y="Age", hue="Gender", ax=axes[1])
axes[1].set_title("LABEL ATTRITION")
# Out:
# Text(0.5, 1.0, 'LABEL ATTRITION')

# %%
# Visualisierung Cluster Vergleich Label "Attrition" mit Label "Cluster"

fig, axes = plt.subplots(1, 2,  figsize=(7, 5))

sns.scatterplot(data=mitarbeiter02, x="MonthlyIncome", y="TotalWorkingYears", hue="Label_K_means", ax=axes[0])
axes[0].set_title("LABEL CLUSTER")

sns.scatterplot(data=mitarbeiter02, x="MonthlyIncome", y="TotalWorkingYears", hue="Attrition", ax=axes[1])
axes[1].set_title("LABEL ATTRITION")
# Out:
# Text(0.5, 1.0, 'LABEL ATTRITION')

# %%
# Vergleich Label "Attrition" mit Label "Cluster" mit PCA

print(classification_report(mitarbeiter02["Attrition"], pred_km))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79      1233
#            1       0.08      0.11      0.10       237
#
#     accuracy                           0.65      1470
#    macro avg       0.45      0.44      0.44      1470
# weighted avg       0.70      0.65      0.67      1470

# %% [markdown]
# # K-Means ohne PCA

# %%
# K-Means mit allen features und Datensatz X01 - alle features

km02 = KMeans(n_clusters=2, random_state=33)  
pred_km02 = km02.fit_predict(X01)

print(classification_report(mitarbeiter02["Attrition"], pred_km02))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79      1233
#            1       0.10      0.14      0.12       237
#
#     accuracy                           0.66      1470
#    macro avg       0.46      0.45      0.45      1470
# weighted avg       0.70      0.66      0.68      1470

# %%
# K-Means mit Datenssatz X02 - features mit höchsten Korrelationen

km03 = KMeans(n_clusters=2, random_state=33)  
pred_km03 = km03.fit_predict(X02)

print(classification_report(mitarbeiter02["Attrition"], pred_km03))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79      1233
#            1       0.10      0.14      0.12       237
#
#     accuracy                           0.66      1470
#    macro avg       0.46      0.45      0.45      1470
# weighted avg       0.70      0.66      0.68      1470

# %%
# K-Means mit Datenssatz X03 - features geringste Korrelationen
# --> günstig wenn features keine hohen Korrelationen untereinander haben - bestes Ergebnis!!

km04 = KMeans(n_clusters=2, random_state=33)  
pred_km04 = km04.fit_predict(X03)

print(classification_report(mitarbeiter02["Attrition"], pred_km04))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.80      1233
#            1       0.20      0.32      0.25       237
#
#     accuracy                           0.69      1470
#    macro avg       0.53      0.54      0.53      1470
# weighted avg       0.75      0.69      0.71      1470

# %%
# - „Alter“ = Das Alter des Mitarbeiters
# - „Abwanderung“ = Gibt an, ob der Mitarbeiter abgewandert ist oder nicht
# - „BusinessTravel“ = Ob der Mitarbeiter geschäftlich unterwegs war oder nicht
# - „Abteilung“ = In welcher Abteilung der Mitarbeiter beschäftigt war
# - „DistanceFromHome“ = Die Distanz, die der Mitarbeiter täglich zurücklegt, um den Job zu erreichen
# - „Geschlecht“ = Geschlecht des Mitarbeiters
# - „JobInvolvement“ = Die Beteiligungsbewertung eines Mitarbeiters an der bearbeiteten Aufgabe
# - „JobLevel“ = Ebene, auf der der Mitarbeiter arbeitet
# - „JobRole“ = Die Rollen und Verantwortlichkeiten des Mitarbeiters
# - „JobSatisfaction“ = Zufriedenheitsbewertung des Mitarbeiters mit der Stelle
# - „MaritalStatus“ = Familienstand des Mitarbeiters
# - „MonthlyIncome“ = Monatliches Einkommen der Mitarbeiter
# - „NumCompaniesWorked“ = Anzahl der Unternehmen, für die die Mitarbeiter gearbeitet haben
# - „OverTime“ = Ob Überstunden gemacht werden oder nicht
# - „PercentSalaryHike“ = Prozentuale Gehaltserhöhung seit ihrer Einstellung im Unternehmen
# - „PerformanceRating“ = Leistungsbewertung
# - „StockOptionLevel“ = Grad der Entscheidung, die Aktie zu teilen
# - „TotalWorkingYears“ = Gesamtarbeitsjahre der Mitarbeiter
# - „TrainingTimesLastYear“ = Wie viele Schulungen hat der Mitarbeiter absolviert
# - „YearsAtCompany“ = Jahre, die bei der aktuellen Organisation verbracht wurden
# - „YearsSinceLastPromotion“ = Zeit in Jahren seit der letzten Beförderung
# - „YearsWithCurrManager“ = Jahre, in denen unter dem aktuellen Manager gearbeitet wurde
# - „Higher_Education“ = Höheres Bildungsniveau des Mitarbeiters
# - „Date_of_Hire“ = Einstellungsdatum des Mitarbeiters in der aktuellen Organisation
# - „Date_of_termination“ = Datum der Kündigung aus der Organisation
# - „Status_of_leaving“ = Grund für den Austritt aus der Organisation
# - „Mode_of_work“ = WFH oder WFO
# - „Urlaub“ = Gesamtzahl der zulässigen Urlaubstage des Mitarbeiters
# - „Abwesenheit“ = Gesamtzahl der Abwesenheitstage des Mitarbeiters
# - „Work_accident“ = Arbeitsunfall, falls vorhanden
# - „Source_of_hire“ = Quelle der Einstellung
# - „Job_Mode“ = Vollzeit-/Teilzeit- oder Vertragsarbeit
